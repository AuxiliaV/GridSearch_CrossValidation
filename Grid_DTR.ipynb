# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset=pd.get_dummies(dataset,drop_first=True).astype(int)
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
para={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],'splitter':['best','random'],'random_state':[20,40,60]}
regressor=GridSearchCV(DecisionTreeRegressor(),para,refit=True,verbose=3,n_jobs=-1)
regressor.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'random_state': [20, 40, 60],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
result=regressor.cv_results_
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.012470      0.001220         0.006045        0.000762
# 1        0.011354      0.001627         0.006365        0.001524
# 2        0.011870      0.001252         0.004842        0.001142
# 3        0.009910      0.000875         0.005387        0.000917
# 4        0.011612      0.000647         0.004709        0.001088
# 5        0.009406      0.000924         0.004694        0.000820
# 6        0.009768      0.000871         0.004342        0.000234
# 7        0.008793      0.000240         0.005514        0.000940
# 8        0.009626      0.001576         0.002663        0.002599
# 9        0.005132      0.002298         0.005983        0.002359
# 10       0.012436      0.001620         0.004118        0.001117
# 11       0.008740      0.000681         0.003959        0.001156
# 12       0.044278      0.001756         0.003829        0.000829
# ...

# %%
import pickle
filename="DTR_Grid_Dataframe.csv"
pickle.dump(table,open(filename,'wb'))

# %%
print("The best scored parameter is: {}".format(regressor.best_params_))
# Out:
# The best scored parameter is: {'criterion': 'squared_error', 'random_state': 60, 'splitter': 'best'}

# %%
pickle.dump(regressor,open("Grid_DTreeR.sav",'wb'))

# %%
model=pickle.load(open("Grid_DTreeR.sav",'rb'))
out=model.predict([[35,40,2,1,1]])
out
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([43753.])
